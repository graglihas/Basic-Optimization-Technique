# %%
from scipy.optimize import minimize_scalar
from scipy.optimize import minimize
from scipy.optimize import fsolve
import math

# %%
def f(x):
  return (x**2)+(54/x)

# %%
a=[1]

# %%
minimize(f,x0=a,method='Powell',,options={'maxiter':2,'disp':True,'return_all': True})
# Out:
# ...
#  allvecs: [array([1.]), array([3.0066741]), array([-0.00020745])]
#    direc: array([[-3.02321071]])
#      fun: array(-260303.56815528)
#  message: 'Maximum number of iterations has been exceeded.'
#     nfev: 51
#      nit: 2
#   status: 2
#  success: False
#        x: array(-0.00020745)
